# %%
import os
print(os.getcwd())
# Out:
# /run/media/bayazid/F9EE-6FF0/windows/Study/Persona/Books/Extra_learnings/langchain

# %%
import sys
# !{sys.executable} -m pip install langchain_ollama
# Out:
# 12843.54s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# ...
#
# [notice] A new release of pip is available: 25.1.1 -> 26.1
# [notice] To update, run: pip install --upgrade pip

# %%
from langchain_ollama import ChatOllama
from dotenv import load_dotenv
import os


llm = ChatOllama(
    model="qwen2.5:0.5b",
    temperature=0.6
)
ans = llm.invoke("What is the capital of Rajshahi??")
print(ans.content)
# Out:
# The capital of Rajshahi is Rajshahi, which is located in Bangladesh. It is situated on the banks of the Brahmaputra River and is part of the larger city of Dhaka. Rajshahi is a provincial capital with its own government office and administrative functions, while Dhaka serves as the provincial capital for the entire country.
